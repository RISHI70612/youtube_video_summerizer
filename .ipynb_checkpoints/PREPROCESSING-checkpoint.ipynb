# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
from IPython.display import YouTubeVideo

# %%
video=input("Enter the link of your YouTube Video: ")
# Out:
# Enter the link of your YouTube Video: https://www.youtube.com/watch?v=Fo-k-Qosy8A

# %%
id_video=video.split("=")[1]
print(id_video)
# Out:
# Fo-k-Qosy8A

# %%
YouTubeVideo(id_video)

# %%
transcript = YouTubeTranscriptApi.get_transcript(id_video)

# %%
transcript
# Out:
# [{'text': 'hi welcome to another episode of Cold',
#   'start': 1.399,
#   'duration': 4.001},
#  {'text': 'Fusion', 'start': 4.08, 'duration': 3.6},
#  {'text': "in cold Fusion's early days back in the",
#   'start': 5.4,
#   'duration': 4.56},
#  {'text': 'early to mid-2010s a lot of Android',
#   'start': 7.68,
#   'duration': 3.839},
#  {'text': 'phones would make their way onto the',
#   'start': 9.96,
#   'duration': 3.599},
#  {'text': 'channel one very common feature among',
#   'start': 11.519,
#   'duration': 3.721},
#  {'text': 'these phones was use a replaceable',
#   'start': 13.559,
#   'duration': 4.501},
#  {'text': 'batteries at the time carrying a spare',
#   'start': 15.24,
#   'duration': 4.2},
#  {'text': "battery in your pocket wasn't that",
#   'start': 18.06,
#   'duration': 3.299},
#  {'text': 'unusual of an occurrent but have you',
#   'start': 19.44,
#   'duration': 3.38},
#  {'text': 'ever wondered what happened to that',
#   'start': 21.359,
#   'duration': 4.08},
#  {'text': 'nowadays thanks to industry-wide design',
#   'start': 22.82,
#   'duration': 5.199},
#  {'text': 'changes glass glue and metals have',
#   'start': 25.439,
#   'duration': 4.021},
#  {'text': 'become the industry standard for',
#   'start': 28.019,
#   'duration': 3.721},
#  {'text': 'materials because of this easily',
#   'start': 29.46,
#   'duration': 3.96},
#  {'text': 'replaceable batteries are no longer',
#   'start': 31.74,
#   'duration': 3.78},
#  {'text': 'possible this just been the way things',
#   'start': 33.42,
#   'duration': 3.54},
#  {'text': 'have been for the better part of a',
#   'start': 35.52,
#   'duration': 4.32},
#  {'text': 'decade but things are about to change in',
#   'start': 36.96,
#   'duration': 4.439},
#  {'text': 'a sweeping new law by the European',
#   'start': 39.84,
#   'duration': 3.48},
#  {'text': 'Parliament replaceable battery products',
#   'start': 41.399,
#   'duration': 4.021},
#  {'text': 'will be forced back into fashion the law',
#   'start': 43.32,
#   'duration': 4.2},
#  {'text': 'will have an effect on phones tablets',
#   'start': 45.42,
#   'duration': 4.56},
#  {'text': 'and laptops not just in Europe but',
#   'start': 47.52,
#   'duration': 5.039},
#  {'text': "worldwide in this episode we'll take a",
#   'start': 49.98,
#   'duration': 4.14},
#  {'text': 'quick look', 'start': 52.559, 'duration': 4.681},
#  {'text': 'we were watching cool Fusion TV', 'start': 54.12, 'duration': 5.88},
#  {'text': '[Music]', 'start': 57.24, 'duration': 5.639},
#  {'text': 'in June of 2023 the European Parliament',
#   'start': 60.0,
#   'duration': 6.299},
#  {'text': 'voted 587 to 9 in a bid to force all',
#   'start': 62.879,
#   'duration': 5.1},
#  {'text': 'consumer devices to have easily',
#   'start': 66.299,
#   'duration': 4.32},
#  {'text': 'replaceable batteries easily replaceable',
#   'start': 67.979,
#   'duration': 4.621},
#  {'text': 'means that the battery changing process',
#   'start': 70.619,
#   'duration': 4.441},
#  {'text': 'should require no special tools this',
#   'start': 72.6,
#   'duration': 4.379},
#  {'text': 'means manufacturers can no longer use',
#   'start': 75.06,
#   'duration': 4.68},
#  {'text': 'adhesives the direct quote from the EU',
#   'start': 76.979,
#   'duration': 4.381},
#  {'text': 'is that battery replacement should',
#   'start': 79.74,
#   'duration': 4.44},
#  {'text': 'require quote no tool or set of tools',
#   'start': 81.36,
#   'duration': 4.439},
#  {'text': 'that is supplied with the product or',
#   'start': 84.18,
#   'duration': 4.2},
#  {'text': 'spare part or basic tools the process',
#   'start': 85.799,
#   'duration': 4.32},
#  {'text': 'for replacement shall be able to be',
#   'start': 88.38,
#   'duration': 3.54},
#  {'text': 'carried out by a Layman', 'start': 90.119, 'duration': 4.081},
#  {'text': 'almost all smartphones today are',
#   'start': 91.92,
#   'duration': 4.379},
#  {'text': 'designed like a glass sandwich this was',
#   'start': 94.2,
#   'duration': 4.02},
#  {'text': 'the design that was settled upon as the',
#   'start': 96.299,
#   'duration': 4.14},
#  {'text': 'smartphone market matured the glass',
#   'start': 98.22,
#   'duration': 4.5},
#  {'text': 'sandwich method of construction is Sleek',
#   'start': 100.439,
#   'duration': 4.381},
#  {'text': 'and thin but relies on an extensive use',
#   'start': 102.72,
#   'duration': 4.259},
#  {'text': 'of adhesives this law would mean that',
#   'start': 104.82,
#   'duration': 3.78},
#  {'text': 'the very fundamentals of how companies',
#   'start': 106.979,
#   'duration': 4.381},
#  {'text': 'design phones will need to change unless',
#   'start': 108.6,
#   'duration': 4.5},
#  {'text': 'companies figure out a new way to build',
#   'start': 111.36,
#   'duration': 3.299},
#  {'text': 'the same phones without adhesives',
#   'start': 113.1,
#   'duration': 3.839},
#  {'text': 'manufacturers from Apple to Google to',
#   'start': 114.659,
#   'duration': 4.14},
#  {'text': 'Samsung will be affected', 'start': 116.939, 'duration': 3.781},
#  {'text': 'foldable phones will face a huge',
#   'start': 118.799,
#   'duration': 3.18},
#  {'text': 'challenge when trying to comply with',
#   'start': 120.72,
#   'duration': 3.0},
#  {'text': "these laws so we'll have to wait and see",
#   'start': 121.979,
#   'duration': 2.761},
#  {'text': 'on that front', 'start': 123.72, 'duration': 3.06},
#  {'text': 'so how does the law in the EU possibly',
#   'start': 124.74,
#   'duration': 4.499},
#  {'text': "affect the rest of the world well it's",
#   'start': 126.78,
#   'duration': 4.14},
#  {'text': "likely that phone manufacturers aren't",
#   'start': 129.239,
#   'duration': 3.661},
#  {'text': 'going to design a specific phone for the',
#   'start': 130.92,
#   'duration': 2.94},
#  {'text': 'EU', 'start': 132.9, 'duration': 3.24},
#  {'text': "reason being it's expensive so it's",
#   'start': 133.86,
#   'duration': 4.26},
#  {'text': 'going to eat into their profit', 'start': 136.14, 'duration': 4.44},
#  {'text': 'Apple for example is unlikely to design',
#   'start': 138.12,
#   'duration': 4.44},
#  {'text': 'a European iPhone with a replaceable',
#   'start': 140.58,
#   'duration': 4.26},
#  {'text': 'battery and another iPhone with a sealed',
#   'start': 142.56,
#   'duration': 4.74},
#  {'text': 'battery for other regions this EU lore',
#   'start': 144.84,
#   'duration': 4.14},
#  {'text': 'will have a Rippling consequence across',
#   'start': 147.3,
#   'duration': 2.7},
#  {'text': 'the world', 'start': 148.98, 'duration': 3.72},
#  {'text': 'but it goes further the law also affects',
#   'start': 150.0,
#   'duration': 6.54},
#  {'text': 'tablets laptops EVS e-bikes and',
#   'start': 152.7,
#   'duration': 5.399},
#  {'text': 'basically anything with a rechargeable',
#   'start': 156.54,
#   'duration': 4.86},
#  {'text': 'battery in July of 2023 the law was',
#   'start': 158.099,
#   'duration': 5.161},
#  {'text': 'approved by the European Council and',
#   'start': 161.4,
#   'duration': 4.559},
#  {'text': 'will come into effect in 2027. this',
#   'start': 163.26,
#   'duration': 4.68},
#  {'text': 'gives over three years for manufacturers',
#   'start': 165.959,
#   'duration': 3.721},
#  {'text': 'to get their act together this will be',
#   'start': 167.94,
#   'duration': 3.6},
#  {'text': 'an especially big change for Apple who',
#   'start': 169.68,
#   'duration': 3.66},
#  {'text': 'have never featured removable batteries',
#   'start': 171.54,
#   'duration': 4.14},
#  {'text': 'since the very first iPhone Samsung',
#   'start': 173.34,
#   'duration': 4.32},
#  {'text': 'stopped featuring removable batteries on',
#   'start': 175.68,
#   'duration': 4.74},
#  {'text': 'their flagships back in 2014. so many',
#   'start': 177.66,
#   'duration': 4.62},
#  {'text': 'people think that waterproofing and dust',
#   'start': 180.42,
#   'duration': 3.72},
#  {'text': 'proofing will be much harder to achieve',
#   'start': 182.28,
#   'duration': 3.78},
#  {'text': 'but right to repair Advocate Lewis',
#   'start': 184.14,
#   'duration': 4.5},
#  {'text': 'Rossman argues some good points so I am',
#   'start': 186.06,
#   'duration': 4.38},
#  {'text': 'old enough to remember when this was not',
#   'start': 188.64,
#   'duration': 4.679},
#  {'text': "a repair but maintenance and I'm also",
#   'start': 190.44,
#   'duration': 4.68},
#  {'text': 'old enough to remember that Society',
#   'start': 193.319,
#   'duration': 4.021},
#  {'text': 'seems to have this Collective Amnesia',
#   'start': 195.12,
#   'duration': 4.38},
#  {'text': 'regarding water resistance there was an',
#   'start': 197.34,
#   'duration': 3.96},
#  {'text': 'article going over this where it said',
#   'start': 199.5,
#   'duration': 3.239},
#  {'text': 'that one needs to be aware that', 'start': 201.3, 'duration': 3.24},
#  {'text': 'incorporating easily removable bags will',
#   'start': 202.739,
#   'duration': 3.0},
#  {'text': 'mean these handsets will lose water',
#   'start': 204.54,
#   'duration': 2.64},
#  {'text': 'resistance unless a well thought out',
#   'start': 205.739,
#   'duration': 3.661},
#  {'text': 'design is undertaken again selective',
#   'start': 207.18,
#   'duration': 3.9},
#  {'text': 'amnesia for the phases like the Samsung',
#   'start': 209.4,
#   'duration': 5.339},
#  {'text': 'S5 which is IP67 or the Sony xb10 which',
#   'start': 211.08,
#   'duration': 7.62},
#  {'text': 'is ip68 this device is ip68 with a user',
#   'start': 214.739,
#   'duration': 5.821},
#  {'text': 'removable battery', 'start': 218.7, 'duration': 3.66},
#  {'text': 'some others argue that removable',
#   'start': 220.56,
#   'duration': 3.84},
#  {'text': 'batteries will make smartphones bulky',
#   'start': 222.36,
#   'duration': 5.4},
#  {'text': 'and less premium but the LG G5 proved',
#   'start': 224.4,
#   'duration': 4.919},
#  {'text': 'that it was possible to make a phone',
#   'start': 227.76,
#   'duration': 4.08},
#  {'text': 'thin premium and with a removable',
#   'start': 229.319,
#   'duration': 4.98},
#  {'text': 'battery right to repair campaigns',
#   'start': 231.84,
#   'duration': 5.1},
#  {'text': 'coordinator Christina gnapi calls the',
#   'start': 234.299,
#   'duration': 5.101},
#  {'text': 'ruling quote a big success for right to',
#   'start': 236.94,
#   'duration': 4.64},
#  {'text': 'repair', 'start': 239.4, 'duration': 2.18},
#  {'text': '[Music]', 'start': 243.36, 'duration': 5.099},
#  {'text': 'for those of you unfamiliar right to',
#   'start': 245.599,
#   'duration': 4.72},
#  {'text': 'repair is a movement that calls for',
#   'start': 248.459,
#   'duration': 3.541},
#  {'text': 'consumer goods to be easily repairable',
#   'start': 250.319,
#   'duration': 4.62},
#  {'text': "we've all seen the trend when your TV or",
#   'start': 252.0,
#   'duration': 4.739},
#  {'text': "phone is broken it's more common for",
#   'start': 254.939,
#   'duration': 3.54},
#  {'text': 'people to just buy a new one instead of',
#   'start': 256.739,
#   'duration': 3.361},
#  {'text': 'repairing it this is due to the',
#   'start': 258.479,
#   'duration': 3.54},
#  {'text': 'components becoming more complex and',
#   'start': 260.1,
#   'duration': 4.26},
#  {'text': 'integrated over time but some companies',
#   'start': 262.019,
#   'duration': 4.561},
#  {'text': 'are straight up anti-consumer in this',
#   'start': 264.36,
#   'duration': 4.92},
#  {'text': 'context apple is the biggest culprit if',
#   'start': 266.58,
#   'duration': 4.559},
#  {'text': 'you own a later model iPhone and the',
#   'start': 269.28,
#   'duration': 3.66},
#  {'text': 'screen breaks and you go to replace it',
#   'start': 271.139,
#   'duration': 3.481},
#  {'text': 'with a perfectly good screen from the',
#   'start': 272.94,
#   'duration': 3.78},
#  {'text': 'same model Apple will disable some',
#   'start': 274.62,
#   'duration': 3.72},
#  {'text': "features and warn you that it's not",
#   'start': 276.72,
#   'duration': 2.58},
#  {'text': 'genuine', 'start': 278.34, 'duration': 2.76},
#  {'text': 'the same goes for replacing the battery',
#   'start': 279.3,
#   'duration': 4.02},
#  {'text': 'or camera and even if they are genuine',
#   'start': 281.1,
#   'duration': 3.659},
#  {'text': "parts but don't have the same serial",
#   'start': 283.32,
#   'duration': 3.36},
#  {'text': "number things don't work as they should",
#   'start': 284.759,
#   'duration': 4.081},
#  {'text': "this wasn't the case for older Apple",
#   'start': 286.68,
#   'duration': 4.079},
#  {'text': "products it's an effort to make their",
#   'start': 288.84,
#   'duration': 3.96},
#  {'text': 'users send their devices only to Apple',
#   'start': 290.759,
#   'duration': 4.201},
#  {'text': 'so an exorbitant fee can be extracted',
#   'start': 292.8,
#   'duration': 4.8},
#  {'text': 'from consumers further to this apple',
#   'start': 294.96,
#   'duration': 5.1},
#  {'text': 'does not supply diagnostic software and',
#   'start': 297.6,
#   'duration': 4.2},
#  {'text': "they've even raided repair shops for",
#   'start': 300.06,
#   'duration': 3.6},
#  {'text': 'having a large stock of genuine repair',
#   'start': 301.8,
#   'duration': 3.3},
#  {'text': 'parts', 'start': 303.66, 'duration': 3.599},
#  {'text': "let's say that in your MacBook you have",
#   'start': 305.1,
#   'duration': 4.319},
#  {'text': 'a broken display Flex cable Apple',
#   'start': 307.259,
#   'duration': 4.141},
#  {'text': 'intentionally connects the display Flex',
#   'start': 309.419,
#   'duration': 3.72},
#  {'text': "Cable in such a way that you can't just",
#   'start': 311.4,
#   'duration': 3.18},
#  {'text': 'replace the cable you have to replace',
#   'start': 313.139,
#   'duration': 3.78},
#  {'text': 'the entire display and this can cost',
#   'start': 314.58,
#   'duration': 5.339},
#  {'text': "over 700 or a wire to it if we're",
#   'start': 316.919,
#   'duration': 5.041},
#  {'text': 'looking at a flex cable a flex cable',
#   'start': 319.919,
#   'duration': 4.681},
#  {'text': "that is less than 50 cents I'm telling",
#   'start': 321.96,
#   'duration': 4.26},
#  {'text': "people I'm telling technicians that get",
#   'start': 324.6,
#   'duration': 3.84},
#  {'text': 'paid 30 to 50 an hour spend an hour',
#   'start': 326.22,
#   'duration': 4.56},
#  {'text': 'trying to fix this Flex cable that costs',
#   'start': 328.44,
#   'duration': 4.199},
#  {'text': "50 cents because we're not allowed to",
#   'start': 330.78,
#   'duration': 3.72},
#  {'text': 'replace it so if the pads are missing we',
#   'start': 332.639,
#   'duration': 3.241},
#  {'text': 'have to start scraping away with a',
#   'start': 334.5,
#   'duration': 2.94},
#  {'text': 'dental pick and hope that we can solder',
#   'start': 335.88,
#   'duration': 3.659},
#  {'text': 'a little jumper wire onto a flex cable',
#   'start': 337.44,
#   'duration': 3.66},
#  {'text': 'to reattach it to a chip that was',
#   'start': 339.539,
#   'duration': 3.121},
#  {'text': 'corroded that we then have to file away',
#   'start': 341.1,
#   'duration': 4.14},
#  {'text': "at to get to the metal because I can't",
#   'start': 342.66,
#   'duration': 5.22},
#  {'text': 'put a new 50 Cent Hall sensor on that',
#   'start': 345.24,
#   'duration': 4.739},
#  {'text': "person's MacBook because if I do it",
#   'start': 347.88,
#   'duration': 4.44},
#  {'text': "won't work I understand the argument for",
#   'start': 349.979,
#   'duration': 4.5},
#  {'text': 'Apple wanting safer repairs but should',
#   'start': 352.32,
#   'duration': 4.2},
#  {'text': 'this mean that even a qualified external',
#   'start': 354.479,
#   'duration': 3.78},
#  {'text': 'repair technician should be blocked from',
#   'start': 356.52,
#   'duration': 3.119},
#  {'text': 'helping people with their damaged',
#   'start': 358.259,
#   'duration': 2.761},
#  {'text': 'devices', 'start': 359.639, 'duration': 3.661},
#  {'text': "of course Apple isn't the only company",
#   'start': 361.02,
#   'duration': 4.26},
#  {'text': 'that does this but for the context of',
#   'start': 363.3,
#   'duration': 4.2},
#  {'text': "this story they're the most relevant",
#   'start': 365.28,
#   'duration': 5.16},
#  {'text': '[Music]', 'start': 367.5, 'duration': 5.639},
#  {'text': "so what's the intention of this law",
#   'start': 370.44,
#   'duration': 4.979},
#  {'text': "the new law isn't for consumers as much",
#   'start': 373.139,
#   'duration': 4.5},
#  {'text': 'as it is to protect the environment',
#   'start': 375.419,
#   'duration': 4.381},
#  {'text': "today when a phone's battery dwindles",
#   'start': 377.639,
#   'duration': 4.201},
#  {'text': "after a few years it's much easier for",
#   'start': 379.8,
#   'duration': 3.72},
#  {'text': 'the common user to just buy a new one',
#   'start': 381.84,
#   'duration': 4.02},
#  {'text': 'instead of repairing it over 50 million',
#   'start': 383.52,
#   'duration': 4.44},
#  {'text': 'annual tons of E-Waste is generated this',
#   'start': 385.86,
#   'duration': 4.38},
#  {'text': 'way the European Parliament is making',
#   'start': 387.96,
#   'duration': 4.019},
#  {'text': 'sure that the environmental impacts of',
#   'start': 390.24,
#   'duration': 3.899},
#  {'text': "batteries is considered they're aiming",
#   'start': 391.979,
#   'duration': 3.84},
#  {'text': 'to create a circular economy for',
#   'start': 394.139,
#   'duration': 2.701},
#  {'text': 'batteries', 'start': 395.819, 'duration': 2.88},
#  {'text': 'this means that in a product life cycle',
#   'start': 396.84,
#   'duration': 3.72},
#  {'text': "as little as possible of the battery's",
#   'start': 398.699,
#   'duration': 4.261},
#  {'text': 'raw materials should be wasted', 'start': 400.56, 'duration': 4.32},
#  {'text': 'here are some rules covered by the law',
#   'start': 402.96,
#   'duration': 4.26},
#  {'text': 'pertaining to replaceable batteries',
#   'start': 404.88,
#   'duration': 4.319},
#  {'text': 'phone manufacturers will need to collect',
#   'start': 407.22,
#   'duration': 4.38},
#  {'text': '63 of portable batteries that would',
#   'start': 409.199,
#   'duration': 4.081},
#  {'text': 'normally go into landfill by the end of',
#   'start': 411.6,
#   'duration': 4.56},
#  {'text': '2027. lithium recovery from waste',
#   'start': 413.28,
#   'duration': 4.5},
#  {'text': 'batteries will need to be at 50 percent',
#   'start': 416.16,
#   'duration': 5.039},
#  {'text': 'by 2027 and EV batteries will need to be',
#   'start': 417.78,
#   'duration': 4.919},
#  {'text': 'made of certain percentages of',
#   'start': 421.199,
#   'duration': 4.741},
#  {'text': 'recyclable content initially 16 Cobalt',
#   'start': 422.699,
#   'duration': 7.56},
#  {'text': '85 lead 6 lithium and six percent nickel',
#   'start': 425.94,
#   'duration': 6.539},
#  {'text': 'all batteries should have a recycling',
#   'start': 430.259,
#   'duration': 5.761},
#  {'text': 'efficiency Target of 50 by 2025.',
#   'start': 432.479,
#   'duration': 5.94},
#  {'text': 'this all sounds fine but the first point',
#   'start': 436.02,
#   'duration': 4.619},
#  {'text': 'seems difficult getting consumers to',
#   'start': 438.419,
#   'duration': 3.481},
#  {'text': 'responsibly give their older phone',
#   'start': 440.639,
#   'duration': 3.12},
#  {'text': 'batteries back to the manufacturer will',
#   'start': 441.9,
#   'duration': 5.01},
#  {'text': "be tricky to enforce we'll have to see",
#   'start': 443.759,
#   'duration': 8.22},
#  {'text': '[Music]', 'start': 446.91, 'duration': 6.87},
#  {'text': "so it's unlikely that there's going to",
#   'start': 451.979,
#   'duration': 3.78},
#  {'text': 'be any changes in the next few months to',
#   'start': 453.78,
#   'duration': 4.5},
#  {'text': 'a year but after this Smartphone makers',
#   'start': 455.759,
#   'duration': 3.961},
#  {'text': 'will have to start gearing up for',
#   'start': 458.28,
#   'duration': 3.66},
#  {'text': "compliance with a new law we'll start to",
#   'start': 459.72,
#   'duration': 3.72},
#  {'text': 'see the results of these efforts over',
#   'start': 461.94,
#   'duration': 3.9},
#  {'text': 'the next few years I did say earlier',
#   'start': 463.44,
#   'duration': 4.259},
#  {'text': "that it's unlikely that manufacturers",
#   'start': 465.84,
#   'duration': 3.54},
#  {'text': 'will Design two different phones an',
#   'start': 467.699,
#   'duration': 3.481},
#  {'text': 'iPhone for Europe and another for the',
#   'start': 469.38,
#   'duration': 3.24},
#  {'text': 'rest of the world but anything is',
#   'start': 471.18,
#   'duration': 2.639},
#  {'text': 'possible really', 'start': 472.62, 'duration': 3.24},
#  {'text': "it's also going to be fascinating to see",
#   'start': 473.819,
#   'duration': 4.741},
#  {'text': 'what happens to laptops e-bikes and EVS',
#   'start': 475.86,
#   'duration': 4.92},
#  {'text': 'regardless things are going to be shaken',
#   'start': 478.56,
#   'duration': 4.079},
#  {'text': 'up in the next few years and an',
#   'start': 480.78,
#   'duration': 3.479},
#  {'text': 'interesting question that I post to you',
#   'start': 482.639,
#   'duration': 3.96},
#  {'text': 'is do you think that the phasing out of',
#   'start': 484.259,
#   'duration': 4.38},
#  {'text': 'user replaceable batteries was just the',
#   'start': 486.599,
#   'duration': 3.72},
#  {'text': 'natural progression of design as',
#   'start': 488.639,
#   'duration': 4.441},
#  {'text': 'dictated by consumer demand or are these',
#   'start': 490.319,
#   'duration': 5.28},
#  {'text': 'changes motivated by profit resulting in',
#   'start': 493.08,
#   'duration': 4.679},
#  {'text': 'anti-consumer products let me know what',
#   'start': 495.599,
#   'duration': 3.54},
#  {'text': 'you think in the comments section below',
#   'start': 497.759,
#   'duration': 3.421},
#  {'text': 'if you want to see another cold fusion',
#   'start': 499.139,
#   'duration': 3.96},
#  {'text': "episode on battery recycling I'll link",
#   'start': 501.18,
#   'duration': 4.739},
#  {'text': 'that below oh and the third and final',
#   'start': 503.099,
#   'duration': 4.741},
#  {'text': 'episode of my AI series with the',
#   'start': 505.919,
#   'duration': 3.84},
#  {'text': 'Australian Broadcasting Corporation will',
#   'start': 507.84,
#   'duration': 3.299},
#  {'text': 'be live soon', 'start': 509.759, 'duration': 2.821},
#  {'text': "I'll leave a link for that in the",
#   'start': 511.139,
#   'duration': 3.96},
#  {'text': 'description below cheers guys have a',
#   'start': 512.58,
#   'duration': 3.66},
#  {'text': 'good one', 'start': 515.099, 'duration': 13.641},
#  {'text': '[Music]', 'start': 516.24, 'duration': 15.56},
#  {'text': 'all right', 'start': 528.74, 'duration': 3.06},
#  {'text': 'all right', 'start': 532.8, 'duration': 5.77},
#  {'text': '[Music]', 'start': 535.53, 'duration': 3.04},
#  {'text': "cold fusion it's me thinking", 'start': 540.8, 'duration': 5.039}]

# %%
doc = ""
for line in transcript:
    doc =doc+ '     ' + line['text']
print(type(doc))
print(doc)
# Out:
# <class 'str'>
#      hi welcome to another episode of Cold     Fusion     in cold Fusion's early days back in the     early to mid-2010s a lot of Android     phones would make their way onto the     channel one very common feature among     these phones was use a replaceable     batteries at the time carrying a spare     battery in your pocket wasn't that     unusual of an occurrent but have you     ever wondered what happened to that     nowadays thanks to industry-wide design     changes glass glue and metals have     become the industry standard for     materials because of this easily     replaceable batteries are no longer     possible this just been the way things     have been for the better part of a     decade but things are about to change in     a sweeping new law by the European     Parliament replaceable battery products     will be forced back into fashion the law     will have an effect on phones tablets     and laptops not just in Europe but     worldwide in this episode we'll take a     quick look     we were watching cool Fusion TV     [Music]     in June of 2023 the European Parliament     voted 587 to 9 in a bid to force all     consumer devices to have easily     replaceable batteries easily replaceable     means that the battery changing process     should require no special tools this     means manufacturers can no longer use     adhesives the direct quote from the EU     is that battery replacement should     require quote no tool or set of tools     that is supplied with the product or     spare part or basic tools the process     for replacement shall be able to be     carried out by a Layman     almost all smartphones today are     designed like a glass sandwich this was     the design that was settled upon as the     smartphone market matured the glass     sandwich method of construction is Sleek     and thin but relies on an extensive use     of adhesives this law would mean that     the very fundamentals of how companies     design phones will need to change unless     companies figure out a new way to build     the same phones without adhesives     manufacturers from Apple to Google to     Samsung will be affected     foldable phones will face a huge     challenge when trying to comply with     these laws so we'll have to wait and see     on that front     so how does the law in the EU possibly     affect the rest of the world well it's     likely that phone manufacturers aren't     going to design a specific phone for the     EU     reason being it's expensive so it's     going to eat into their profit     Apple for example is unlikely to design     a European iPhone with a replaceable     battery and another iPhone with a sealed     battery for other regions this EU lore     will have a Rippling consequence across     the world     but it goes further the law also affects     tablets laptops EVS e-bikes and     basically anything with a rechargeable     battery in July of 2023 the law was     approved by the European Council and     will come into effect in 2027. this     gives over three years for manufacturers     to get their act together this will be     an especially big change for Apple who     have never featured removable batteries     since the very first iPhone Samsung     stopped featuring removable batteries on     their flagships back in 2014. so many     people think that waterproofing and dust     proofing will be much harder to achieve     but right to repair Advocate Lewis     Rossman argues some good points so I am     old enough to remember when this was not     a repair but maintenance and I'm also     old enough to remember that Society     seems to have this Collective Amnesia     regarding water resistance there was an     article going over this where it said     that one needs to be aware that     incorporating easily removable bags will     mean these handsets will lose water     resistance unless a well thought out     design is undertaken again selective     amnesia for the phases l ...

# %%
doc = []
for line in transcript: 
    if "\n" in line["text"]:
        x = line["text"].replace("\n" , "")
        doc.append(x)
    else: 
        doc.append(line["text"])
print(doc)
# Out:
# ['hi welcome to another episode of Cold', 'Fusion', "in cold Fusion's early days back in the", 'early to mid-2010s a lot of Android', 'phones would make their way onto the', 'channel one very common feature among', 'these phones was use a replaceable', 'batteries at the time carrying a spare', "battery in your pocket wasn't that", 'unusual of an occurrent but have you', 'ever wondered what happened to that', 'nowadays thanks to industry-wide design', 'changes glass glue and metals have', 'become the industry standard for', 'materials because of this easily', 'replaceable batteries are no longer', 'possible this just been the way things', 'have been for the better part of a', 'decade but things are about to change in', 'a sweeping new law by the European', 'Parliament replaceable battery products', 'will be forced back into fashion the law', 'will have an effect on phones tablets', 'and laptops not just in Europe but', "worldwide in this episode we'll take a", 'quick look', 'we were watching cool Fusion TV', '[Music]', 'in June of 2023 the European Parliament', 'voted 587 to 9 in a bid to force all', 'consumer devices to have easily', 'replaceable batteries easily replaceable', 'means that the battery changing process', 'should require no special tools this', 'means manufacturers can no longer use', 'adhesives the direct quote from the EU', 'is that battery replacement should', 'require quote no tool or set of tools', 'that is supplied with the product or', 'spare part or basic tools the process', 'for replacement shall be able to be', 'carried out by a Layman', 'almost all smartphones today are', 'designed like a glass sandwich this was', 'the design that was settled upon as the', 'smartphone market matured the glass', 'sandwich method of construction is Sleek', 'and thin but relies on an extensive use', 'of adhesives this law would mean that', 'the very fundamentals of how companies', 'design phones will need to change unless', 'companies figure out a new way to build', 'the same phones without adhesives', 'manufacturers from Apple to Google to', 'Samsung will be affected', 'foldable phones will face a huge', 'challenge when trying to comply with', "these laws so we'll have to wait and see", 'on that front', 'so how does the law in the EU possibly', "affect the rest of the world well it's", "likely that phone manufacturers aren't", 'going to design a specific phone for the', 'EU', "reason being it's expensive so it's", 'going to eat into their profit', 'Apple for example is unlikely to design', 'a European iPhone with a replaceable', 'battery and another iPhone with a sealed', 'battery for other regions this EU lore', 'will have a Rippling consequence across', 'the world', 'but it goes further the law also affects', 'tablets laptops EVS e-bikes and', 'basically anything with a rechargeable', 'battery in July of 2023 the law was', 'approved by the European Council and', 'will come into effect in 2027. this', 'gives over three years for manufacturers', 'to get their act together this will be', 'an especially big change for Apple who', 'have never featured removable batteries', 'since the very first iPhone Samsung', 'stopped featuring removable batteries on', 'their flagships back in 2014. so many', 'people think that waterproofing and dust', 'proofing will be much harder to achieve', 'but right to repair Advocate Lewis', 'Rossman argues some good points so I am', 'old enough to remember when this was not', "a repair but maintenance and I'm also", 'old enough to remember that Society', 'seems to have this Collective Amnesia', 'regarding water resistance there was an', 'article going over this where it said', 'that one needs to be aware that', 'incorporating easily removable bags will', 'mean these handsets will lose water', 'resistance unless a well thought out', 'design is undertaken again selective', 'amnesia for the phases like the Samsung', 'S5 which is IP67 or the Sony xb10 which', 'is ip68 this device is ip68 with a user', ...

# %%
paragraph=" ".join(doc)
print(paragraph)
# Out:
# hi welcome to another episode of Cold Fusion in cold Fusion's early days back in the early to mid-2010s a lot of Android phones would make their way onto the channel one very common feature among these phones was use a replaceable batteries at the time carrying a spare battery in your pocket wasn't that unusual of an occurrent but have you ever wondered what happened to that nowadays thanks to industry-wide design changes glass glue and metals have become the industry standard for materials because of this easily replaceable batteries are no longer possible this just been the way things have been for the better part of a decade but things are about to change in a sweeping new law by the European Parliament replaceable battery products will be forced back into fashion the law will have an effect on phones tablets and laptops not just in Europe but worldwide in this episode we'll take a quick look we were watching cool Fusion TV [Music] in June of 2023 the European Parliament voted 587 to 9 in a bid to force all consumer devices to have easily replaceable batteries easily replaceable means that the battery changing process should require no special tools this means manufacturers can no longer use adhesives the direct quote from the EU is that battery replacement should require quote no tool or set of tools that is supplied with the product or spare part or basic tools the process for replacement shall be able to be carried out by a Layman almost all smartphones today are designed like a glass sandwich this was the design that was settled upon as the smartphone market matured the glass sandwich method of construction is Sleek and thin but relies on an extensive use of adhesives this law would mean that the very fundamentals of how companies design phones will need to change unless companies figure out a new way to build the same phones without adhesives manufacturers from Apple to Google to Samsung will be affected foldable phones will face a huge challenge when trying to comply with these laws so we'll have to wait and see on that front so how does the law in the EU possibly affect the rest of the world well it's likely that phone manufacturers aren't going to design a specific phone for the EU reason being it's expensive so it's going to eat into their profit Apple for example is unlikely to design a European iPhone with a replaceable battery and another iPhone with a sealed battery for other regions this EU lore will have a Rippling consequence across the world but it goes further the law also affects tablets laptops EVS e-bikes and basically anything with a rechargeable battery in July of 2023 the law was approved by the European Council and will come into effect in 2027. this gives over three years for manufacturers to get their act together this will be an especially big change for Apple who have never featured removable batteries since the very first iPhone Samsung stopped featuring removable batteries on their flagships back in 2014. so many people think that waterproofing and dust proofing will be much harder to achieve but right to repair Advocate Lewis Rossman argues some good points so I am old enough to remember when this was not a repair but maintenance and I'm also old enough to remember that Society seems to have this Collective Amnesia regarding water resistance there was an article going over this where it said that one needs to be aware that incorporating easily removable bags will mean these handsets will lose water resistance unless a well thought out design is undertaken again selective amnesia for the phases like the Samsung S5 which is IP67 or the Sony xb10 which is ip68 this device is ip68 with a user removable battery some others argue that removable batteries will make smartphones bulky and less premium but the LG G5 proved that it was possible to make a phone thin premium and with a removable battery right to repair campaigns coordinator Christina gnapi calls the ruling quote a big success for right to ...
